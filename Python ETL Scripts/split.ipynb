# %%
import pandas as pd
import os

path = r"D:\Swapnil\Work\Projects\FIFA\Updated Base Files"
file = os.path.join(path, "Step9_Final_Dataset.csv")

chunk_size = 200000  # adjust if needed

for i, chunk in enumerate(pd.read_csv(file, chunksize=chunk_size)):
    chunk.to_csv(os.path.join(path, f"part_{i}.csv"), index=False)

print("Done splitting")
# Out:
# Done splitting
