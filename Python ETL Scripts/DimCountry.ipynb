# %%
import pandas as pd
import os

folder_path = r"D:\Swapnil\Work\Projects\FIFA\Base_Files"

countries_data = [
    ["Canada","North America","CONCACAF",1,1,"High",1.20],
    ["Mexico","North America","CONCACAF",1,1,"High",1.25],
    ["United States","North America","CONCACAF",1,1,"High",1.30],
    ["Argentina","South America","CONMEBOL",1,0,"High",1.25],
    ["Brazil","South America","CONMEBOL",1,0,"High",1.30],
    ["Colombia","South America","CONMEBOL",1,0,"Medium",1.05],
    ["Ecuador","South America","CONMEBOL",1,0,"Medium",1.00],
    ["Paraguay","South America","CONMEBOL",1,0,"Low",0.85],
    ["Uruguay","South America","CONMEBOL",1,0,"Medium",1.00],
    ["Austria","Europe","UEFA",1,0,"Medium",1.00],
    ["Belgium","Europe","UEFA",1,0,"High",1.10],
    ["Bosnia and Herzegovina","Europe","UEFA",1,0,"Low",0.85],
    ["Croatia","Europe","UEFA",1,0,"Medium",1.00],
    ["Czechia","Europe","UEFA",1,0,"Medium",0.95],
    ["England","Europe","UEFA",1,0,"High",1.25],
    ["France","Europe","UEFA",1,0,"High",1.25],
    ["Germany","Europe","UEFA",1,0,"High",1.25],
    ["Netherlands","Europe","UEFA",1,0,"High",1.15],
    ["Norway","Europe","UEFA",1,0,"Medium",0.95],
    ["Portugal","Europe","UEFA",1,0,"High",1.15],
    ["Scotland","Europe","UEFA",1,0,"Medium",0.95],
    ["Spain","Europe","UEFA",1,0,"High",1.20],
    ["Sweden","Europe","UEFA",1,0,"Medium",1.00],
    ["Switzerland","Europe","UEFA",1,0,"Medium",1.05],
    ["Turkey","Europe","UEFA",1,0,"Medium",1.05],
    ["Australia","Asia-Pacific","AFC",1,0,"Medium",1.05],
    ["Iran","Asia","AFC",1,0,"Medium",0.95],
    ["Japan","Asia","AFC",1,0,"High",1.15],
    ["Jordan","Asia","AFC",1,0,"Low",0.80],
    ["Qatar","Asia","AFC",1,0,"Medium",1.00],
    ["Saudi Arabia","Asia","AFC",1,0,"Medium",1.05],
    ["South Korea","Asia","AFC",1,0,"High",1.10],
    ["Uzbekistan","Asia","AFC",1,0,"Low",0.80],
    ["Iraq","Asia","AFC",1,0,"Low",0.80],
    ["Algeria","Africa","CAF",1,0,"Medium",0.95],
    ["Cape Verde","Africa","CAF",1,0,"Low",0.75],
    ["DR Congo","Africa","CAF",1,0,"Low",0.80],
    ["Egypt","Africa","CAF",1,0,"Medium",1.00],
    ["Ghana","Africa","CAF",1,0,"Medium",0.95],
    ["Ivory Coast","Africa","CAF",1,0,"Medium",0.95],
    ["Morocco","Africa","CAF",1,0,"Medium",1.00],
    ["Senegal","Africa","CAF",1,0,"Medium",0.95],
    ["South Africa","Africa","CAF",1,0,"Medium",1.00],
    ["Tunisia","Africa","CAF",1,0,"Medium",0.90],
    ["Curaçao","North America","CONCACAF",1,0,"Low",0.75],
    ["Haiti","North America","CONCACAF",1,0,"Low",0.75],
    ["Panama","North America","CONCACAF",1,0,"Medium",0.90],
    ["New Zealand","Oceania","OFC",1,0,"Medium",0.95],
]

dim_country = pd.DataFrame(
    countries_data,
    columns=[
        "country",
        "region",
        "confederation",
        "is_world_cup_team",
        "is_host",
        "tier",
        "country_multiplier"
    ]
)

dim_country.insert(0, "country_id", range(1, len(dim_country) + 1))

output_path = os.path.join(folder_path, "Dim_Country.xlsx")
dim_country.to_excel(output_path, index=False)

print("Saved:", output_path)
print("Rows, columns:", dim_country.shape)
print(dim_country.head())
# Out:
# Saved: D:\Swapnil\Work\Projects\FIFA\Base_Files\Dim_Country.xlsx
# Rows, columns: (48, 8)
#    country_id        country         region confederation  is_world_cup_team  \
# 0           1         Canada  North America      CONCACAF                  1
# 1           2         Mexico  North America      CONCACAF                  1
# 2           3  United States  North America      CONCACAF                  1
# 3           4      Argentina  South America      CONMEBOL                  1
# 4           5         Brazil  South America      CONMEBOL                  1
#
#    is_host  tier  country_multiplier
# 0        1  High                1.20
# 1        1  High                1.25
# 2        1  High                1.30
# 3        0  High                1.25
# 4        0  High                1.30

# %%
import pandas as pd

file_path = r"D:\Swapnil\Work\Projects\FIFA\Base_Files\Dim_Country.xlsx"

df = pd.read_excel(file_path)

print(df.shape)
print(df.columns)
print(df.head())
# Out:
# (48, 8)
# Index(['country_id', 'country', 'region', 'confederation', 'is_world_cup_team',
#        'is_host', 'tier', 'country_multiplier'],
#       dtype='object')
#    country_id        country         region confederation  is_world_cup_team  \
# 0           1         Canada  North America      CONCACAF                  1
# 1           2         Mexico  North America      CONCACAF                  1
# 2           3  United States  North America      CONCACAF                  1
# 3           4      Argentina  South America      CONMEBOL                  1
# 4           5         Brazil  South America      CONMEBOL                  1
#
#    is_host  tier  country_multiplier
# 0        1  High                1.20
# 1        1  High                1.25
# 2        1  High                1.30
# 3        0  High                1.25
# 4        0  High                1.30
